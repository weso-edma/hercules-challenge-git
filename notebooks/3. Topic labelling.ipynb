# %% [markdown]
# # 3. Topic labelling

# %% [markdown]
# ## Setup
# As always, we will begin by loading a set of constants and initializing the logging system. Since we will be using Bokeh in this notebook, we will configure it to output the results in the Jupyter notebook:

# %%
# %run __init__.py

# %%
from bokeh.io import output_notebook

output_notebook()
# Out:
# /home/alejandro/.envs/edma/lib/python3.7/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
import pandas as pd

GIT_FILE_PATH = os.path.join(NOTEBOOK_1_RESULTS_DIR, 'git_dataframe.pkl')

git_df = pd.read_pickle(GIT_FILE_PATH)
git_repositories = git_df['full_text_cleaned'].values

# %% [markdown]
# ## Entity linking

# %% [markdown]
# ### Using the entity linking class
# An entity linking class has been defined in the _entity_linking.py_ module of the _src_ directory. This class will link the given words to their Wikidata entity by using the [wbsearchentities](https://www.wikidata.org/w/api.php?action=help&modules=wbsearchentities) modules from the MediaWiki API:

# %%
from herc_common.entity_linking import WikidataEntityLinker

entity_linker = WikidataEntityLinker()
res = entity_linker.link_entity('python')
res
# Out:
# ('python', 'http://www.wikidata.org/entity/Q28865')

# %% [markdown]
# ### Linking each topic's term to Wikidata
# In the following cells we are going to load the lda model trained on the Agriculture dataset, obtain the term distribution of each topic, and link each term to Wikidata. We will start by loading both the LDA pipeline and the document term matrix with the term frequency:

# %%
from herc_common.utils import load_object

lda_agriculture_pipe_filename = "git_nmf_model.pkl"
dtm_tf_filename = "git_dtm_tfidf.pkl"

lda_pipe = load_object(os.path.join(NOTEBOOK_2_RESULTS_DIR, lda_agriculture_pipe_filename))
dtm_tf = load_object(os.path.join(NOTEBOOK_2_RESULTS_DIR, dtm_tf_filename))

# %% [markdown]
# In order to obtain the list of terms for each topic, we are going to make use of the _get\_topic\_terms\_by\_relevance_ function to obtain a list of more relevant terms for each topic (see [Sievert & Shirley](https://nlp.stanford.edu/events/illvi2014/papers/sievert-illvi2014.pdf) for more information).

# %%
from herc_common.utils import get_topic_terms_by_relevance

def link_topic_terms(entity_linker, model, vectorizer,
                     dtm_tf, n_top_words, lambda_=0.6):
    res = []
    if lambda_ < 1.0:
        topic_terms = get_topic_terms_by_relevance(model, vectorizer, dtm_tf,
                                                   n_top_words, lambda_)
    else:
        feature_names = vectorizer.get_feature_names()
        topic_terms = [[feature_names[i] for i in topic.argsort()[:-n_top_words - 1: -1]] 
                       for topic in model.components_]
    return [[entity_linker.link_entity(entity) for entity in topic]
            for topic in topic_terms]

# %% [markdown]
# Finally, we can make used of the function defined above to link each term to Wikidata. The output of the following cell will be a 2D array, with the first dimension corresponding to each topic, and the second one consisting on tuples containing the pair ('term', 'wikidata_uri') for every term of the topic:

# %%
linked_terms = link_topic_terms(entity_linker, lda_pipe.named_steps['model'],
                                lda_pipe.named_steps['vectorizer'], dtm_tf, 
                                n_top_words=10, lambda_=1)
linked_terms
# Out:
# [[('base', 'http://www.wikidata.org/entity/Q191360'),
#   ('Command', 'http://www.wikidata.org/entity/Q1079196'),
#   ('array', 'http://www.wikidata.org/entity/Q186152'),
#   ('Index', 'http://www.wikidata.org/entity/Q873506'),
#   ('create', 'http://www.wikidata.org/entity/Q30218413'),
#   ('Operation', 'http://www.wikidata.org/entity/Q1079196'),
#   ('core', 'http://www.wikidata.org/entity/Q23595'),
#   ('base base', 'http://www.wikidata.org/entity/Q35556177'),
#   ('sesame', 'http://www.wikidata.org/entity/Q18028187'),
#   ('dialog', 'http://www.wikidata.org/entity/Q131395')],
#  [('biosample', 'http://www.wikidata.org/entity/Q4914649'),
#   ('BioSample', 'http://www.wikidata.org/entity/Q4914649'),
#   ('BioSample RDF', None),
#   ('BioSample record', None),
#   ('record', 'http://www.wikidata.org/entity/Q49848'),
#   ('RDF', 'http://www.wikidata.org/entity/Q54872'),
#   ('BioHackathon', 'http://www.wikidata.org/entity/Q27975958'),
#   ('EBI biosample', None),
#   ('xml', 'http://www.wikidata.org/entity/Q2115'),
#   ('discussion', 'http://www.wikidata.org/entity/Q3030248')],
#  [('Formik', 'http://www.wikidata.org/entity/Q95968826'),
#   ('app', 'http://www.wikidata.org/entity/Q166142'),
#   ('eject', 'http://www.wikidata.org/entity/Q12948722'),
#   ('npm', 'http://www.wikidata.org/entity/Q540668'),
#   ('example Formik', None),
#   ('React', 'http://www.wikidata.org/entity/Q19399674'),
#   ('build', 'http://www.wikidata.org/entity/Q183252'),
#   ('mode', 'http://www.wikidata.org/entity/Q184932'),
#   ('Validation example', None),
#   ('open view', None)],
#  [('mpcc', 'http://www.wikidata.org/entity/Q720284'),
#   ('optimize', 'http://www.wikidata.org/entity/Q7098967'),
#   ('MKL', 'http://www.wikidata.org/entity/Q24719504'),
#   ('version', 'http://www.wikidata.org/entity/Q3331189'),
#   ('Pearsons', 'http://www.wikidata.org/entity/Q26634081'),
#   ('coefficient', 'http://www.wikidata.org/entity/Q50700'),
#   ('optimize version', None),
#   ('correlation coefficient', 'http://www.wikidata.org/entity/Q1136628'),
#   ('Intel MKL', 'http://www.wikidata.org/entity/Q6786762'),
#   ('Pearsons correlation', None)],
#  [('concept', 'http://www.wikidata.org/entity/Q151885'),
#   ('tbox', 'http://www.wikidata.org/entity/Q19929551'),
#   ('abox', 'http://www.wikidata.org/entity/Q4668674'),
#   ('subsumption', 'http://www.wikidata.org/entity/Q1294556'),
#   ('format', 'http://www.wikidata.org/entity/Q21502404'),
#   ('expansion', 'http://www.wikidata.org/entity/Q17281278'),
#   ('check', 'http://www.wikidata.org/entity/Q80042'),
#   ('axiom', 'http://www.wikidata.org/entity/Q17736'),
#   ('consistency', 'http://www.wikidata.org/entity/Q1319773'),
#   ('relationname', None)],
#  [('sort', 'http://www.wikidata.org/entity/Q12690'),
#   ('Heap', 'http://www.wikidata.org/entity/Q180987'),
#   ('Linked List', 'http://www.wikidata.org/entity/Q7003418'),
#   ('Pointer', 'http://www.wikidata.org/entity/Q11175'),
#   ('Linked', 'http://www.wikidata.org/entity/Q73897190'),
#   ('Makefile', 'http://www.wikidata.org/entity/Q20748783'),
#   ('Implementing Str', 'http://www.wikidata.org/entity/Q46768810'),
#   ('Algorithm', 'http://www.wikidata.org/entity/Q8366'),
#   ('Str', 'http://www.wikidata.org/entity/Q265193'),
#   ('Implementing', 'http://www.wikidata.org/entity/Q245962')],
#  [('sentence', 'http://www.wikidata.org/entity/Q41796'),
#   ('Wasserstein', 'http://www.wikidata.org/entity/Q56244663'),
#   ('daily', 'http://www.wikidata.org/entity/Q26214163'),
#   ('latent', 'http://www.wikidata.org/entity/Q6495507'),
#   ('latent space', 'http://www.wikidata.org/entity/Q42511961'),
#   ('train', 'http://www.wikidata.org/entity/Q870'),
#   ('snli', 'http://www.wikidata.org/entity/Q29520368'),
#   ('valid', 'http://www.wikidata.org/entity/Q1047000'),
#   ('space', 'http://www.wikidata.org/entity/Q1'),
#   ('generation', 'http://www.wikidata.org/entity/Q213381')],
#  [('jetty', 'http://www.wikidata.org/entity/Q3082251'),
#   ('Kefed', None),
#   ('powerloom', 'http://www.wikidata.org/entity/Q7236790'),
#   ('system', 'http://www.wikidata.org/entity/Q58778'),
#   ('small', 'http://www.wikidata.org/entity/Q2590065'),
#   ('ball', 'http://www.wikidata.org/entity/Q18545'),
#   ('tab', 'http://www.wikidata.org/entity/Q302526'),
#   ('pin', 'http://www.wikidata.org/entity/Q324926'),
#   ('Template', 'http://www.wikidata.org/entity/Q11266439'),
#   ('Data', 'http://www.wikidata.org/entity/Q42848')],
#  [('unimath', None),
#   ('Disp', 'http://www.wikidata.org/entity/Q3497709'),
#   ('Bicat', 'http://www.wikidata.org/entity/Q33237209'),
#   ('Functor', 'http://www.wikidata.org/entity/Q864475'),
#   ('Functors', 'http://www.wikidata.org/entity/Q2120608'),
#   ('Category', 'http://www.wikidata.org/entity/Q4167836'),
#   ('Categories', 'http://www.wikidata.org/entity/Q1735826'),
#   ('Pseudo', 'http://www.wikidata.org/entity/Q2598033'),
#   ('Monads', 'http://www.wikidata.org/entity/Q51029463'),
#   ('Strict', 'http://www.wikidata.org/entity/Q7623608')],
#  [('classifier', 'http://www.wikidata.org/entity/Q63153'),
#   ('xgb', 'http://www.wikidata.org/entity/Q29822507'),
#   ('music', 'http://www.wikidata.org/entity/Q638'),
#   ('checkpoint', 'http://www.wikidata.org/entity/Q402459'),
#   ('vgg', 'http://www.wikidata.org/entity/Q1279167'),
#   ('curve', 'http://www.wikidata.org/entity/Q161973'),
#   ('xgb classifier', None),
#   ('feature', 'http://www.wikidata.org/entity/Q1207505'),
#   ('Genre Classification', None),
#   ('Music Genre', 'http://www.wikidata.org/entity/Q188451')],
#  [('Calculate', 'http://www.wikidata.org/entity/Q622821'),
#   ('Meme', 'http://www.wikidata.org/entity/Q2927074'),
#   ('Terms', 'http://www.wikidata.org/entity/Q21071941'),
#   ('Wos', 'http://www.wikidata.org/entity/Q1201886'),
#   ('Data', 'http://www.wikidata.org/entity/Q42848'),
#   ('directory', 'http://www.wikidata.org/entity/Q2352616'),
#   ('calculate meme', None),
#   ('Comm', 'http://www.wikidata.org/entity/Q24785009'),
#   ('Prepare', 'http://www.wikidata.org/entity/Q86290974'),
#   ('meme score', None)],
#  [('function function', 'http://www.wikidata.org/entity/Q45959390'),
#   ('function', 'http://www.wikidata.org/entity/Q11348'),
#   ('chall', 'http://www.wikidata.org/entity/Q37265721'),
#   ('plot', 'http://www.wikidata.org/entity/Q683595'),
#   ('que', 'http://www.wikidata.org/entity/Q176'),
#   ('jupyter', 'http://www.wikidata.org/entity/Q55630549'),
#   ('episode', 'http://www.wikidata.org/entity/Q1983062'),
#   ('icon', 'http://www.wikidata.org/entity/Q132137'),
#   ('touch icon', None),
#   ('apple touch', None)],
#  [('reasoner', 'http://www.wikidata.org/entity/Q3929429'),
#   ('cui', 'http://www.wikidata.org/entity/Q49115'),
#   ('asthma', 'http://www.wikidata.org/entity/Q35869'),
#   ('output yaml', None),
#   ('NCATS', 'http://www.wikidata.org/entity/Q16787735'),
#   ('query output', None),
#   ('NCATS reasoner', None),
#   ('yaml suitable', None),
#   ('suitable import', None),
#   ('list cui', None)],
#  [('virtuoso', 'http://www.wikidata.org/entity/Q214970'),
#   ('miscellanelous stuff', None),
#   ('course lose', None),
#   ('stuff train', None),
#   ('train course', None),
#   ('lose delete', None),
#   ('dav', 'http://www.wikidata.org/entity/Q513666'),
#   ('virtuoso entrypoint', None),
#   ('place miscellanelous', None),
#   ('miscellanelous', None)],
#  [('controller', 'http://www.wikidata.org/entity/Q865422'),
#   ('html', 'http://www.wikidata.org/entity/Q8811'),
#   ('spec', 'http://www.wikidata.org/entity/Q2101564'),
#   ('helper', 'http://www.wikidata.org/entity/Q23835475'),
#   ('project', 'http://www.wikidata.org/entity/Q170584'),
#   ('controller spec', None),
#   ('rename', 'http://www.wikidata.org/entity/Q7312524'),
#   ('associate', 'http://www.wikidata.org/entity/Q47165448'),
#   ('span', 'http://www.wikidata.org/entity/Q185759'),
#   ('denotation', 'http://www.wikidata.org/entity/Q1189753')],
#  [('html', 'http://www.wikidata.org/entity/Q8811'),
#   ('textile', 'http://www.wikidata.org/entity/Q28823'),
#   ('html textile', None),
#   ('job', 'http://www.wikidata.org/entity/Q192581'),
#   ('collection', 'http://www.wikidata.org/entity/Q208165'),
#   ('container', 'http://www.wikidata.org/entity/Q987767'),
#   ('controller', 'http://www.wikidata.org/entity/Q865422'),
#   ('pipeline', 'http://www.wikidata.org/entity/Q16885408'),
#   ('arvados', None),
#   ('user', 'http://www.wikidata.org/entity/Q278368')],
#  [('poly', 'http://www.wikidata.org/entity/Q1531473'),
#   ('poly log', 'http://www.wikidata.org/entity/Q55951524'),
#   ('log', 'http://www.wikidata.org/entity/Q193472'),
#   ('season', 'http://www.wikidata.org/entity/Q27020041'),
#   ('player', 'http://www.wikidata.org/entity/Q937857'),
#   ('reduce feature', None),
#   ('log reduce', None),
#   ('feature', 'http://www.wikidata.org/entity/Q1207505'),
#   ('reduce', 'http://www.wikidata.org/entity/Q1857633'),
#   ('scaler', 'http://www.wikidata.org/entity/Q4352951')],
#  [('virtualenv', None),
#   ('uploader', 'http://www.wikidata.org/entity/Q9020729'),
#   ('enter', 'http://www.wikidata.org/entity/Q1007162'),
#   ('enter virtualenv', None),
#   ('tool', 'http://www.wikidata.org/entity/Q39546'),
#   ('sudo apt', None),
#   ('apt', 'http://www.wikidata.org/entity/Q207632'),
#   ('sudo', 'http://www.wikidata.org/entity/Q300883'),
#   ('sequence', 'http://www.wikidata.org/entity/Q133250'),
#   ('use', 'http://www.wikidata.org/entity/Q1724915')],
#  [('hashsplitter', None),
#   ('conformance', 'http://www.wikidata.org/entity/Q5160260'),
#   ('cwl', 'http://www.wikidata.org/entity/Q8994'),
#   ('cwl hashsplitter', None),
#   ('task', 'http://www.wikidata.org/entity/Q759676'),
#   ('funnel', 'http://www.wikidata.org/entity/Q170477'),
#   ('conformance test', 'http://www.wikidata.org/entity/Q4072285'),
#   ('test', 'http://www.wikidata.org/entity/Q4115189'),
#   ('server', 'http://www.wikidata.org/entity/Q157195'),
#   ('Funnel', 'http://www.wikidata.org/entity/Q170477')],
#  [('figure', 'http://www.wikidata.org/entity/Q29527347'),
#   ('Generalizability', 'http://www.wikidata.org/entity/Q24633726'),
#   ('Crisis', 'http://www.wikidata.org/entity/Q381072'),
#   ('Generalizability Crisis', None),
#   ('Yarkoni Generalizability', None),
#   ('Yarkoni', 'http://www.wikidata.org/entity/Q60632254'),
#   ('datum code', None),
#   ('cislak', 'http://www.wikidata.org/entity/Q36951637'),
#   ('susa', 'http://www.wikidata.org/entity/Q180773'),
#   ('Report Schooler', None)],
#  [('aspnetcoreapp', None),
#   ('bootstrap', 'http://www.wikidata.org/entity/Q893195'),
#   ('cshtml', None),
#   ('csproj', None),
#   ('aspnetcoreapp csproj', None),
#   ('jquery validate', None),
#   ('jquery', 'http://www.wikidata.org/entity/Q230036'),
#   ('min', 'http://www.wikidata.org/entity/Q7727'),
#   ('css', 'http://www.wikidata.org/entity/Q515838'),
#   ('css bootstrap', None)],
#  [('support material', 'http://www.wikidata.org/entity/Q46350610'),
#   ('fahrenheit', 'http://www.wikidata.org/entity/Q42289'),
#   ('teach', 'http://www.wikidata.org/entity/Q372859'),
#   ('celsius', 'http://www.wikidata.org/entity/Q25267'),
#   ('geometry', 'http://www.wikidata.org/entity/Q8087'),
#   ('celsius fahrenheit', None),
#   ('material teach', None),
#   ('material', 'http://www.wikidata.org/entity/Q214609'),
#   ('temp', 'http://www.wikidata.org/entity/Q11466'),
#   ('support', 'http://www.wikidata.org/entity/Q1058733')],
#  [('wikidata', 'http://www.wikidata.org/entity/Q2013'),
#   ('match', 'http://www.wikidata.org/entity/Q13406554'),
#   ('ontomatcher', None),
#   ('match ontology', None),
#   ('ontology', 'http://www.wikidata.org/entity/Q324254'),
#   ('triple', 'http://www.wikidata.org/entity/Q581390'),
#   ('class', 'http://www.wikidata.org/entity/Q37517'),
#   ('entity', 'http://www.wikidata.org/entity/Q56061'),
#   ('ontology class', None),
#   ('ontology Wikidata', None)],
#  [('pogo', 'http://www.wikidata.org/entity/Q840880'),
#   ('pogoentry', None),
#   ('import', 'http://www.wikidata.org/entity/Q62955'),
#   ('clusteredpsmreport', None),
#   ('library', 'http://www.wikidata.org/entity/Q7075'),
#   ('unique', 'http://www.wikidata.org/entity/Q992635'),
#   ('public', 'http://www.wikidata.org/entity/Q211198'),
#   ('Entry', 'http://www.wikidata.org/entity/Q10389811'),
#   ('pogo entry', None),
#   ('tab delimit', None)],
#  [('encode', 'http://www.wikidata.org/entity/Q1134833'),
#   ('Huffman Table', None),
#   ('decode', 'http://www.wikidata.org/entity/Q2011725'),
#   ('Huffman', 'http://www.wikidata.org/entity/Q28801023'),
#   ('dna sequence', 'http://www.wikidata.org/entity/Q23933850'),
#   ('dna', 'http://www.wikidata.org/entity/Q7430'),
#   ('compression', 'http://www.wikidata.org/entity/Q2493'),
#   ('Table', 'http://www.wikidata.org/entity/Q14748'),
#   ('Table generate', None),
#   ('text contain', None)],
#  [('Axiom', 'http://www.wikidata.org/entity/Q17736'),
#   ('Property', 'http://www.wikidata.org/entity/Q1400881'),
#   ('Impl', 'http://www.wikidata.org/entity/Q3340274'),
#   ('Builder', 'http://www.wikidata.org/entity/Q1340643'),
#   ('OWLOntology', None),
#   ('Format', 'http://www.wikidata.org/entity/Q21502404'),
#   ('Factory', 'http://www.wikidata.org/entity/Q83405'),
#   ('OWLObject', None),
#   ('Axiom Impl', None),
#   ('Visitor', 'http://www.wikidata.org/entity/Q830719')],
#  [('Termite', 'http://www.wikidata.org/entity/Q546583'),
#   ('Service', 'http://www.wikidata.org/entity/Q7406919'),
#   ('Similarity', 'http://www.wikidata.org/entity/Q254465'),
#   ('termite', 'http://www.wikidata.org/entity/Q546583'),
#   ('common', 'http://www.wikidata.org/entity/Q286022'),
#   ('Termite Service', None),
#   ('Service Similarity', None),
#   ('api termite', None),
#   ('Service Impl', 'http://www.wikidata.org/entity/Q37373527'),
#   ('Similarity Service', None)],
#  [('stability', 'http://www.wikidata.org/entity/Q392536'),
#   ('quality', 'http://www.wikidata.org/entity/Q1207505'),
#   ('quality quality', None),
#   ('stability stability', None),
#   ('agro', 'http://www.wikidata.org/entity/Q397245'),
#   ('obo', 'http://www.wikidata.org/entity/Q7072326'),
#   ('optimal', 'http://www.wikidata.org/entity/Q18629570'),
#   ('datum datum', None),
#   ('metric', 'http://www.wikidata.org/entity/Q232405'),
#   ('Global', 'http://www.wikidata.org/entity/Q13780930')],
#  [('html', 'http://www.wikidata.org/entity/Q8811'),
#   ('bill', 'http://www.wikidata.org/entity/Q47433'),
#   ('spec', 'http://www.wikidata.org/entity/Q2101564'),
#   ('vote', 'http://www.wikidata.org/entity/Q189760'),
#   ('committee', 'http://www.wikidata.org/entity/Q865588'),
#   ('controller', 'http://www.wikidata.org/entity/Q865422'),
#   ('document', 'http://www.wikidata.org/entity/Q49848'),
#   ('create', 'http://www.wikidata.org/entity/Q30218413'),
#   ('page', 'http://www.wikidata.org/entity/Q1069725'),
#   ('state', 'http://www.wikidata.org/entity/Q7275')],
#  [('dataset', 'http://www.wikidata.org/entity/Q1172284'),
#   ('dataresource dataset', None),
#   ('rdfapi registry', None),
#   ('issuelicense', None),
#   ('new issuelicense', None),
#   ('phplib', None),
#   ('issuelicense application', None),
#   ('dataset description', 'http://www.wikidata.org/entity/Q56992828'),
#   ('owlapi phplib', None),
#   ('utility library', 'http://www.wikidata.org/entity/Q33316915')],
#  [('music', 'http://www.wikidata.org/entity/Q638'),
#   ('weight', 'http://www.wikidata.org/entity/Q11423'),
#   ('model', 'http://www.wikidata.org/entity/Q4610556'),
#   ('generate', 'http://www.wikidata.org/entity/Q5532546'),
#   ('Music', 'http://www.wikidata.org/entity/Q638'),
#   ('epoch', 'http://www.wikidata.org/entity/Q2703'),
#   ('kera', 'http://www.wikidata.org/entity/Q56251'),
#   ('generate music', None),
#   ('tune', 'http://www.wikidata.org/entity/Q170412'),
#   ('quality', 'http://www.wikidata.org/entity/Q1207505')],
#  [('mmtf', 'http://www.wikidata.org/entity/Q33807098'),
#   ('cmake', 'http://www.wikidata.org/entity/Q1023904'),
#   ('load mmtf', None),
#   ('decoder', 'http://www.wikidata.org/entity/Q745243'),
#   ('compile', 'http://www.wikidata.org/entity/Q383538'),
#   ('encoder', 'http://www.wikidata.org/entity/Q5392830'),
#   ('MMTF', 'http://www.wikidata.org/entity/Q33807098'),
#   ('ninja', 'http://www.wikidata.org/entity/Q9402'),
#   ('include', 'http://www.wikidata.org/entity/Q6014791'),
#   ('MessagePack', 'http://www.wikidata.org/entity/Q6821738')],
#  [('lirical', None),
#   ('Command', 'http://www.wikidata.org/entity/Q1079196'),
#   ('Lirical', None),
#   ('likelihood', 'http://www.wikidata.org/entity/Q80968385'),
#   ('likelihood ratio', 'http://www.wikidata.org/entity/Q6547271'),
#   ('phenopacket', None),
#   ('ratio', 'http://www.wikidata.org/entity/Q3481047'),
#   ('phenotype', 'http://www.wikidata.org/entity/Q104053'),
#   ('Simulator', 'http://www.wikidata.org/entity/Q2057931'),
#   ('Phenopacket', None)],
#  [('termite', 'http://www.wikidata.org/entity/Q546583'),
#   ('texpress', None),
#   ('docstore', None),
#   ('demo', 'http://www.wikidata.org/entity/Q220935'),
#   ('demo texpress', None),
#   ('texpress demo', None),
#   ('termite demo', None),
#   ('demo termite', None),
#   ('pprint', None),
#   ('toolkit', 'http://www.wikidata.org/entity/Q1193246')],
#  [('trackhub', None),
#   ('pipeline', 'http://www.wikidata.org/entity/Q16885408'),
#   ('application', 'http://www.wikidata.org/entity/Q166142'),
#   ('process', 'http://www.wikidata.org/entity/Q3249551'),
#   ('given', 'http://www.wikidata.org/entity/Q62065509'),
#   ('ensembl', 'http://www.wikidata.org/entity/Q1344256'),
#   ('PRIDE', 'http://www.wikidata.org/entity/Q187234'),
#   ('trackhub creation', None),
#   ('given project', None),
#   ('project', 'http://www.wikidata.org/entity/Q170584')],
#  [('protein', 'http://www.wikidata.org/entity/Q8054'),
#   ('annotation', 'http://www.wikidata.org/entity/Q857525'),
#   ('structure', 'http://www.wikidata.org/entity/Q6671777'),
#   ('sequence datum', None),
#   ('map', 'http://www.wikidata.org/entity/Q4006'),
#   ('annotation annotation', None),
#   ('contribution', 'http://www.wikidata.org/entity/Q237302'),
#   ('position', 'http://www.wikidata.org/entity/Q4164871'),
#   ('coronavirus', 'http://www.wikidata.org/entity/Q82069695'),
#   ('structural', 'http://www.wikidata.org/entity/Q936724')],
#  [('Connection', 'http://www.wikidata.org/entity/Q930933'),
#   ('Statement', 'http://www.wikidata.org/entity/Q2684591'),
#   ('Handler', 'http://www.wikidata.org/entity/Q1205349'),
#   ('Mysql', 'http://www.wikidata.org/entity/Q850'),
#   ('Exception', 'http://www.wikidata.org/entity/Q779608'),
#   ('Category Handler', 'http://www.wikidata.org/entity/Q5614905'),
#   ('Category', 'http://www.wikidata.org/entity/Q4167836'),
#   ('Regression', 'http://www.wikidata.org/entity/Q208042'),
#   ('Fabric', 'http://www.wikidata.org/entity/Q28823'),
#   ('Pdb', 'http://www.wikidata.org/entity/Q766195')],
#  [('scanner', 'http://www.wikidata.org/entity/Q82744'),
#   ('finder', 'http://www.wikidata.org/entity/Q910951'),
#   ('ruby', 'http://www.wikidata.org/entity/Q161053'),
#   ('NERD', 'http://www.wikidata.org/entity/Q650031'),
#   ('vim', 'http://www.wikidata.org/entity/Q131382'),
#   ('Vim', 'http://www.wikidata.org/entity/Q131382'),
#   ('jump', 'http://www.wikidata.org/entity/Q1151752'),
#   ('buffer', 'http://www.wikidata.org/entity/Q208465'),
#   ('window', 'http://www.wikidata.org/entity/Q35473'),
#   ('match', 'http://www.wikidata.org/entity/Q13406554')],
#  [('job', 'http://www.wikidata.org/entity/Q192581'),
#   ('cwltool', None),
#   ('tool', 'http://www.wikidata.org/entity/Q39546'),
#   ('workflow', 'http://www.wikidata.org/entity/Q627335'),
#   ('package', 'http://www.wikidata.org/entity/Q13107365'),
#   ('CWL', 'http://www.wikidata.org/entity/Q8994'),
#   ('re', 'http://www.wikidata.org/entity/Q17070'),
#   ('cwl', 'http://www.wikidata.org/entity/Q8994'),
#   ('plugin', 'http://www.wikidata.org/entity/Q184148'),
#   ('output', 'http://www.wikidata.org/entity/Q1150771')],
#  [('dropdown', 'http://www.wikidata.org/entity/Q5308446'),
#   ('cell', 'http://www.wikidata.org/entity/Q7868'),
#   ('color', 'http://www.wikidata.org/entity/Q1075'),
#   ('false', 'http://www.wikidata.org/entity/Q5432619'),
#   ('font', 'http://www.wikidata.org/entity/Q208820'),
#   ('webpack', 'http://www.wikidata.org/entity/Q22909730'),
#   ('align', 'http://www.wikidata.org/entity/Q4726571'),
#   ('row', 'http://www.wikidata.org/entity/Q1366302'),
#   ('border', 'http://www.wikidata.org/entity/Q133346'),
#   ('Font', 'http://www.wikidata.org/entity/Q208820')],
#  [('Property', 'http://www.wikidata.org/entity/Q1400881'),
#   ('spec', 'http://www.wikidata.org/entity/Q2101564'),
#   ('Elda', 'http://www.wikidata.org/entity/Q608985'),
#   ('Utils', 'http://www.wikidata.org/entity/Q95958203'),
#   ('Renderer', None),
#   ('Query', 'http://www.wikidata.org/entity/Q11169'),
#   ('Player', 'http://www.wikidata.org/entity/Q937857'),
#   ('apispec', None),
#   ('min', 'http://www.wikidata.org/entity/Q7727'),
#   ('Context', 'http://www.wikidata.org/entity/Q196626')],
#  [('sentence', 'http://www.wikidata.org/entity/Q41796'),
#   ('npuserstudy', None),
#   ('table', 'http://www.wikidata.org/entity/Q14748'),
#   ('npuserstudy npuserstudy', None),
#   ('AIDA', 'http://www.wikidata.org/entity/Q403821'),
#   ('AIDA sentence', None),
#   ('aida', 'http://www.wikidata.org/entity/Q403821'),
#   ('spotlight', 'http://www.wikidata.org/entity/Q18154496'),
#   ('uri', 'http://www.wikidata.org/entity/Q12404'),
#   ('Tobias', 'http://www.wikidata.org/entity/Q4928115')],
#  [('lirical', None),
#   ('Lirical', None),
#   ('Command', 'http://www.wikidata.org/entity/Q1079196'),
#   ('ratio', 'http://www.wikidata.org/entity/Q3481047'),
#   ('phenopacket', None),
#   ('likelihood ratio', 'http://www.wikidata.org/entity/Q6547271'),
#   ('likelihood', 'http://www.wikidata.org/entity/Q80968385'),
#   ('Exception', 'http://www.wikidata.org/entity/Q779608'),
#   ('hpo', 'http://www.wikidata.org/entity/Q29813249'),
#   ('LIRICAL', None)],
#  [('Cheat', 'http://www.wikidata.org/entity/Q1004599'),
#   ('Data', 'http://www.wikidata.org/entity/Q42848'),
#   ('Learning', 'http://www.wikidata.org/entity/Q133500'),
#   ('Sheet', 'http://www.wikidata.org/entity/Q391788'),
#   ('Cheat Sheet', 'http://www.wikidata.org/entity/Q2309859'),
#   ('Data Science', 'http://www.wikidata.org/entity/Q2374463'),
#   ('Machine Learning', 'http://www.wikidata.org/entity/Q2539'),
#   ('Machine', 'http://www.wikidata.org/entity/Q11019'),
#   ('Science', 'http://www.wikidata.org/entity/Q336'),
#   ('cheatsheet', 'http://www.wikidata.org/entity/Q2309859')],
#  [('typeahead', 'http://www.wikidata.org/entity/Q7860918'),
#   ('min', 'http://www.wikidata.org/entity/Q7727'),
#   ('bootstrap', 'http://www.wikidata.org/entity/Q893195'),
#   ('handlebar jquery', None),
#   ('ontologysearch', None),
#   ('bloodhound', 'http://www.wikidata.org/entity/Q21098'),
#   ('view bootstrap', None),
#   ('vc manage', None),
#   ('admin model', None),
#   ('typeahead min', None)],
#  [('TSNE', 'http://www.wikidata.org/entity/Q38440477'),
#   ('Prot', 'http://www.wikidata.org/entity/Q8054'),
#   ('Uni Prot', None),
#   ('Uni', 'http://www.wikidata.org/entity/Q3918'),
#   ('Prep TSNE', None),
#   ('Plants', 'http://www.wikidata.org/entity/Q756'),
#   ('Plants Plot', None),
#   ('Plot Plotly', None),
#   ('opa flopotsne', None),
#   ('Prot Prep', None)],
#  [('prov', 'http://www.wikidata.org/entity/Q176'),
#   ('pass', 'http://www.wikidata.org/entity/Q23069713'),
#   ('pass prov', None),
#   ('prov property', None),
#   ('Prov', 'http://www.wikidata.org/entity/Q176'),
#   ('influence', 'http://www.wikidata.org/entity/Q18603649'),
#   ('property', 'http://www.wikidata.org/entity/Q1400881'),
#   ('toolbox', 'http://www.wikidata.org/entity/Q1501161'),
#   ('Round Trip', 'http://www.wikidata.org/entity/Q7371165'),
#   ('Trip', 'http://www.wikidata.org/entity/Q860266')],
#  [('graph', 'http://www.wikidata.org/entity/Q17514'),
#   ('odgi', 'http://www.wikidata.org/entity/Q72987086'),
#   ('main', 'http://www.wikidata.org/entity/Q1670'),
#   ('dynamic', 'http://www.wikidata.org/entity/Q113558'),
#   ('sort', 'http://www.wikidata.org/entity/Q12690'),
#   ('node', 'http://www.wikidata.org/entity/Q756100'),
#   ('gfa', 'http://www.wikidata.org/entity/Q473231'),
#   ('path', 'http://www.wikidata.org/entity/Q5004679'),
#   ('kmer', 'http://www.wikidata.org/entity/Q1962553'),
#   ('build', 'http://www.wikidata.org/entity/Q183252')],
#  [('crate', 'http://www.wikidata.org/entity/Q275031'),
#   ('Crate', 'http://www.wikidata.org/entity/Q275031'),
#   ('preview', 'http://www.wikidata.org/entity/Q622550'),
#   ('read crate', None),
#   ('entity', 'http://www.wikidata.org/entity/Q56061'),
#   ('write', 'http://www.wikidata.org/entity/Q709113'),
#   ('Entity', 'http://www.wikidata.org/entity/Q56061'),
#   ('list', 'http://www.wikidata.org/entity/Q13406463'),
#   ('metadata', 'http://www.wikidata.org/entity/Q180160'),
#   ('ERB', 'http://www.wikidata.org/entity/Q37538413')],
#  [('codon', 'http://www.wikidata.org/entity/Q165052'),
#   ('transcript', 'http://www.wikidata.org/entity/Q2448947'),
#   ('codon find', None),
#   ('position', 'http://www.wikidata.org/entity/Q4164871'),
#   ('initiation', 'http://www.wikidata.org/entity/Q594939'),
#   ('initiation codon', 'http://www.wikidata.org/entity/Q1854186'),
#   ('reading frame', 'http://www.wikidata.org/entity/Q923372'),
#   ('wild', 'http://www.wikidata.org/entity/Q206357'),
#   ('reading', 'http://www.wikidata.org/entity/Q161491'),
#   ('variation', 'http://www.wikidata.org/entity/Q224581')],
#  [('gifs', 'http://www.wikidata.org/entity/Q35983412'),
#   ('animate gifs', None),
#   ('animate', 'http://www.wikidata.org/entity/Q51927507'),
#   ('colorbox', 'http://www.wikidata.org/entity/Q813112'),
#   ('jquery colorbox', None),
#   ('colorbox jquery', None),
#   ('jquery', 'http://www.wikidata.org/entity/Q230036'),
#   ('trait', 'http://www.wikidata.org/entity/Q2393196'),
#   ('sort', 'http://www.wikidata.org/entity/Q12690'),
#   ('computer animate', 'http://www.wikidata.org/entity/Q28968258')]]

# %% [markdown]
# ## Obtaining each topic's graphs
# In this phase we are going to explore the neighbourhood of each term linked before, to obtain a graph with their related terms from Wikidata. Each set of terms obtained before will be the seed concepts used to obtain the final graph, and a set of properties from Wikidata will be explored recursively to expand the final graph.
#
# For more information about the implementation of the graph building process, the class used can be accessed at the _graph.py_ module in the source directory.
#
# In the following cell we will be configuring the graph builder to build a graph with a maxium depth of two from every seed node. Higher depth values might cause the resulting topic labels to be very general, while with a smaller value we have the risk of not obtaining a connection between the seed nodes:

# %%
from herc_common.graph import WikidataGraphBuilder

graph_builder = WikidataGraphBuilder(max_hops=2)
topic_graphs = [graph_builder.build_graph(topic) for topic in linked_terms]

# %% [markdown]
# Now that we have obtained the neighbourhood graph of each topic, we are going to plot the results using bokeh. Each node will have a different color depending on their depth with respect to the seed nodes, which will be painted in blue. This will allow us to perform an initial exploration of these graphs:

# %%
from bokeh.io import show
from bokeh.layouts import gridplot

from herc_common.bokeh_utils import build_graph_plot


plots = [build_graph_plot(g, f"Topic {idx}") 
         for idx, g in enumerate(topic_graphs)]
grid = gridplot(plots, ncols=2)
show(grid)
# Out:
#   <div class="bk-root" id="53a98cae-bc4a-459d-91b5-13dc1d0b110f" data-root-id="3912"></div>

# %% [markdown]
# An optimum result would be to have every seed term connected in the final graph. However, theere will be some subgraphs which are isolated from the main ones. In the following section we will be solving this issue.

# %% [markdown]
# ## Getting the main connected subgraph
# As we have described before, some of the topic graphs that we have obtained are not fully connected. Small subgraphs which are isolated from the main subgraph will be considered as noise, and removed before the following computations.
#
# In the following cells, we are going to retrieve the largest connected subgraph from each topic's graph, and plot the results to anaylise them:

# %%
from herc_common.graph import get_largest_connected_subgraph

connected_topic_subgraphs = [get_largest_connected_subgraph(g) 
                             for g in topic_graphs]

# %%
plots = [build_graph_plot(g, f"Largest Connected subgraph for topic {idx}") 
         for idx, g in enumerate(connected_topic_subgraphs)]
grid = gridplot(plots, ncols=2)
show(grid)
# Out:
#   <div class="bk-root" id="0c49dac0-a5d7-4781-a7a6-bb3f658339b0" data-root-id="14269"></div>

# %% [markdown]
# In this section we are aiming to see big graphs with the most amount of seed nodes possible. Graphs with few seed nodes from the original term distribution will tend to be less representative of the original topic.

# %% [markdown]
# ## Obtaining the main component of each topic
# Now that we have the final subgraph for each topic, we will be applying several centrality measures to obtain the node that best represents the topic. In the following cell we have defined an auxiliary function that receives a list of algorithm and returns the results of applying them to obtain the best _n_ entities that represent each topic:

# %%
import networkx.algorithms as nxa

from herc_common.graph import get_centrality_algorithm_results

def try_centrality_algorithms(topic_subgraphs, algorithms, stop_uris, top_n=4):
    markdown = ""
    for (algorithm, name) in algorithms:
        print(f'Algorithm: {name}')
        results = [get_centrality_algorithm_results(g, algorithm, stop_uris, top_n)
                   for g in topic_subgraphs]
        results_labels = [[(node[0]['label'], node[1]) for node in topic] 
                          for topic in results]
        for idx, result in enumerate(results_labels):
            print(f"Topic {idx}:", result)
            print()
        print()

        
algorithms = [
    (nxa.centrality.information_centrality, "Information centrality"),
    (nxa.centrality.eigenvector_centrality_numpy, "Eigenvector centrality"),
    (nxa.centrality.closeness_centrality, "Closeness centrality"),
    (nxa.centrality.betweenness_centrality, "Betweenness centrality"),
    (nxa.centrality.communicability_betweenness_centrality, "Communicability betweenness centrality")
]

try_centrality_algorithms(connected_topic_subgraphs,
               algorithms,
               ['Q4167836', 'Q11862829'])
# Out:
# Algorithm: Information centrality
# Topic 0: [('database', 0.009411764705882354), ('work', 0.008830022075055186), ('index', 0.008438818565400845), ('construction', 0.008179959100204501)]
#
# Topic 1: [('library science', 0.006641208699983401), ('document', 0.006386715631486514), ('text', 0.005729838132072767), ('written work', 0.005684240443370754)]
#
# Topic 2: [('software', 0.007148659626320076), ('application', 0.006825409136740873), ('computer program', 0.006605614772556669), ('biology', 0.006140106056377339)]
#
# Topic 3: [('protein', 0.016107382550335586), ('first-order metaclass', 0.012806830309498397), ('Probable ABC transporter ATP-binding protein MlaF/Mkl', 0.011753183153770816), ('protein family', 0.011483253588516764)]
#
# Topic 4: [('concept', 0.04411764705882353), ('abstract object', 0.03846153846153847), ('variable-order metaclass', 0.037500000000000026), ('mental representation', 0.03260869565217392)]
#
# Topic 5: [('computer science', 0.004768428749835668), ('algorithm', 0.0047227867595152516), ('mathematics', 0.004690334859401064), ('algorithmics', 0.004674426167121544)]
#
# Topic 6: [('cosmology', 0.007034110618616311), ('universe', 0.006766777901371901), ('observable universe', 0.006455606650159175), ('cosmology', 0.005848421727287297)]
#
# Topic 7: [('system', 0.007737656595431092), ('structure', 0.006981382978723404), ('systems engineering', 0.006441717791411044), ('cybernetics', 0.006441717791411037)]
#
# Topic 8: [('function', 0.03030303030303031), ('functor', 0.028571428571428577), ('category theory', 0.02439024390243903), ('function value', 0.019607843137254905)]
#
# Topic 9: [('music', 0.002086241996386088), ('specialty', 0.001948061643939483), ('aspect of music', 0.0019018588834268976), ('music genre', 0.0018854064944244008)]
#
# Topic 10: [('catalogue', 0.011064381303631148), ('work', 0.0101296870707127), ('information', 0.009942510092976534), ('written work', 0.009898986754657672)]
#
# Topic 11: [('mathematics', 0.019213973799126642), ('function', 0.018755328218243817), ('mathematical concept', 0.015569709837225758), ('binary relation', 0.01485482781904119)]
#
# Topic 12: [('Cornell University', 0.06444683136412462), ('private university', 0.05176876617773944), ('private not-for-profit educational institution', 0.04662004662004665), ('land-grant university', 0.04491017964071858)]
#
# Topic 13: [('virtuoso', 0.04938271604938271), ('music interpreter', 0.04494382022471911), ('instrumentalist', 0.043010752688172046), ('occupation', 0.04123711340206186)]
#
# Topic 14: [('HyperText Markup Language', 0.01276995305164319), ('technical standard', 0.011995060857294057), ('specification', 0.011877729257641934), ('W3C Recommendation', 0.011617973688706647)]
#
# Topic 15: [('textile', 0.0025746232170851986), ('artificial physical object', 0.002539139047945144), ('clothing', 0.0025371811780257806), ('artificial entity', 0.002465512568355221)]
#
# Topic 16: [('Reduce', 0.017543859649122806), ('computer algebra system', 0.017241379310344827), ('science', 0.014705882352941176), ('free software', 0.01282051282051282)]
#
# Topic 17: [('property', 0.012698412698412691), ('entity', 0.012383900928792576), ('use', 0.011799410029498539), ('converter', 0.011799410029498525)]
#
# Topic 18: [('Earth', 0.021276595744680854), ('Wikidata Sandbox', 0.018518518518518514), ('book', 0.015873015873015876), ('geology', 0.013513513513513516)]
#
# Topic 19: [('Susa', 0.026143790849673196), ('archaeological site', 0.024096385542168676), ('landmark', 0.02061855670103093), ('human-geographic territorial entity', 0.019900497512437814)]
#
# Topic 20: [('minute', 0.039280896785897), ('hour', 0.037926078950913884), ('second', 0.03775820441741928), ('unit of time', 0.03627888993899819)]
#
# Topic 21: [('mathematics', 0.013796384395813498), ('area of mathematics', 0.013242009132420086), ('materials science', 0.012877442273534625), ('branch of science', 0.011471518987341766)]
#
# Topic 22: [('Wikidata', 0.011304136612772063), ('knowledge base', 0.009734041682505102), ('knowledge graph', 0.009099703987581422), ('MediaWiki encyclopedia', 0.008989413252666)]
#
# Topic 23: [('library science', 0.003949967083607651), ('library', 0.0037998733375554147), ('document', 0.0035067212156633656), ('building', 0.0033426183844011167)]
#
# Topic 24: [('DNA', 0.009435336266224661), ('nucleic acid', 0.008457930852327595), ('polynucleotide', 0.00822679353917833), ('nucleotides', 0.008215925354452194)]
#
# Topic 25: [('operation', 0.014101057579318453), ('factory', 0.013808975834292286), ('goods', 0.012779552715654955), ('business', 0.011916583912611717)]
#
# Topic 26: [('service', 0.014359280915108382), ('economics', 0.013667614983404457), ('economic sector', 0.013547094659295867), ('business', 0.013256911588012439)]
#
# Topic 27: [('quality', 0.06666666666666667), ('property', 0.06666666666666665), ('philosophical concept', 0.05263157894736837), ('Category:Qualities', 0.04347826086956521)]
#
# Topic 28: [('document', 0.003732615924399335), ('work', 0.00371786649465299), ('intellectual work', 0.0036241216784995995), ('written work', 0.0036043071002296043)]
#
# Topic 29: [('Utility library for structural bioinformatics.', 0.05), ('scholarly article', 0.04999999999999998), ('bioinformatics', 0.04545454545454545), ('Dataset Descriptions for Linked Data Systems', 0.033333333333333326)]
#
# Topic 30: [('music', 0.008380633118738346), ('art', 0.00737487848211593), ('musicology', 0.0072801879612164585), ('music theory', 0.00723803257114656)]
#
# Topic 31: [('codec', 0.011385199240986727), ('build automation', 0.010434782608695658), ('software feature', 0.009966777408637884), ('software category', 0.009966777408637882)]
#
# Topic 32: [('software', 0.01098901098901099), ('simulator', 0.010869565217391304), ('simulation', 0.009523809523809525), ('computer program', 0.009259259259259259)]
#
# Topic 33: [('widget toolkit', 0.020547945205479454), ('software category', 0.02), ('graphics library', 0.018750000000000006), ('class', 0.016666666666666663)]
#
# Topic 34: [('pipeline transport', 0.009519901518260154), ('pipeline', 0.009002716336825775), ('piping', 0.008914162760316612), ('economic branch', 0.008617487556645126)]
#
# Topic 35: [('protein', 0.0030731646909406903), ('biological process', 0.0029537266836905936), ('group or class of chemical substances', 0.0028089304112786147), ('biopolymer', 0.0028025907891322714)]
#
# Topic 36: [('textile', 0.006443676410286452), ('product', 0.005910483047659989), ('artificial physical object', 0.005872931126534982), ('clothing', 0.005836782341080343)]
#
# Topic 37: [('software', 0.008902583236628101), ('economic branch', 0.008380336720209653), ('Vim', 0.008232102469120362), ('integrated development environment', 0.007799864646634142)]
#
# Topic 38: [('work', 0.00701567897953761), ('activity', 0.006918601603857649), ('workflow', 0.006613557793476634), ('entity', 0.0063882301698688524)]
#
# Topic 39: [('cell', 0.01336913248773262), ('tissue', 0.012389744997769162), ('multicellular structure', 0.011913601636882666), ('biological component', 0.011694012082732703)]
#
# Topic 40: [('document', 0.017647058823529415), ('specification', 0.01595744680851063), ('technical standard', 0.015306122448979593), ('text', 0.015228426395939089)]
#
# Topic 41: [('film', 0.04545454545454544), ('Spotlight', 0.03125), ('series', 0.026315789473684216), ('title sequence', 0.026315789473684216)]
#
# Topic 42: [('Protein kinase domain', 0.007283261876789394), ('Protein kinase, ATP binding site', 0.007274276534855605), ('Hippo Dmel_CG11228', 0.006835819361105435), ('Protein kinase-like domain superfamily', 0.0063638542566506456)]
#
# Topic 43: [('computer science', 0.002122683124970815), ('artificial intelligence', 0.0021138868483012666), ('data science', 0.0021132003561623097), ('statistics', 0.0020869401368720695)]
#
# Topic 44: [('minute', 0.039280896785897), ('hour', 0.03792607895091392), ('second', 0.03775820441741926), ('unit of time', 0.0362788899389982)]
#
# Topic 45: [('protein', 0.003159277374581796), ('biological process', 0.0030370681307607724), ('first-order metaclass', 0.0029924955475726283), ('biopolymer', 0.002921923637962276)]
#
# Topic 46: [('property', 0.031250000000000014), ('entity', 0.03030303030303032), ('goods', 0.028571428571428605), ('disposition', 0.023809523809523843)]
#
# Topic 47: [('graffiti', 0.03157894736842106), ('art genre', 0.026086956521739143), ('work', 0.025862068965517248), ('street art', 0.025641025641025647)]
#
# Topic 48: [('information', 0.005095344707789692), ('metadata', 0.004824914101908025), ('data', 0.004694668705765188), ('secondary information', 0.004650998907719943)]
#
# Topic 49: [('codon', 0.018867924528301883), ('messenger RNA', 0.015873015873015872), ('start codon', 0.014925373134328358), ('standard genetic code', 0.014084507042253521)]
#
# Topic 50: [('jQuery', 0.059701492537313446), ('software library', 0.0575539568345324), ('JavaScript library', 0.054421768707483005), ('software category', 0.04597701149425287)]
#
#
# Algorithm: Eigenvector centrality
# Topic 0: [('database', 0.6510243659075945), ('index', 0.3004455834282246), ('collection', 0.2278874842428074), ('work', 0.20345024155795693)]
#
# Topic 1: [('document', 0.46103870226019), ('text', 0.4003996499585014), ('library science', 0.3812737986546991), ('written work', 0.3040224006398725)]
#
# Topic 2: [('biology', 0.5327165168993215), ('software', 0.3455372943243429), ('morphology', 0.2333077365639031), ('computer program', 0.22936723671279993)]
#
# Topic 3: [('protein', 0.704260082621068), ('first-order metaclass', 0.1390066022895114), ('Probable ABC transporter ATP-binding protein MlaF/Mkl', 0.134149835944969), ('microtubule polymerization based protein transport', 0.12410767547874184)]
#
# Topic 4: [('variable-order metaclass', 0.5718113340621223), ('concept', 0.4808719512837688), ('abstract object', 0.45277617728657277), ('mental representation', 0.20683083591952253)]
#
# Topic 5: [('mathematics', 0.615547158520548), ('computer science', 0.2765347935937446), ('algorithm', 0.2530504047388712), ('academic major', 0.20170768461814764)]
#
# Topic 6: [('observable universe', 0.46104964967423734), ('cosmology', 0.42465919195186685), ('universe', 0.3617430786954191), ('logic', 0.26259063718179965)]
#
# Topic 7: [('system', 0.4444193895157985), ('systems engineering', 0.3158973282678486), ('cybernetics', 0.31589732826784833), ('architectural structure', 0.2665283754960689)]
#
# Topic 8: [('function', 0.6803363925262994), ('functor', 0.27777346815936244), ('function value', 0.20170041710591463), ('multivalued function', 0.20170041710591463)]
#
# Topic 9: [('protein', 0.6983309541300848), ('X globin', 0.172960191973093), ('Leghaemoglobin', 0.16063773995238417), ('first-order metaclass', 0.12432782523312928)]
#
# Topic 10: [('catalogue', 0.5053449361955162), ('knowledge organization system', 0.3395290943729716), ('bibliographic database', 0.33786612203674843), ('collection', 0.3062002603846642)]
#
# Topic 11: [('mathematics', 0.6388166916830477), ('function', 0.3440489795995442), ('mathematical concept', 0.22789227790595895), ('category theory', 0.15956766422148844)]
#
# Topic 12: [('Cornell University', 0.5932917904944225), ('private university', 0.36236744761678813), ('private not-for-profit educational institution', 0.2902078472421429), ('land-grant university', 0.2748654804678535)]
#
# Topic 13: [('music interpreter', 0.47241881775112443), ('virtuoso', 0.44737301961429304), ('instrumentalist', 0.3847469764960407), ('occupation', 0.35887354975225627)]
#
# Topic 14: [('document', 0.5367907240917982), ('technical standard', 0.4196075856657774), ('specification', 0.36293158886513316), ('HyperText Markup Language', 0.20227370510518075)]
#
# Topic 15: [('textile', 0.507424017341375), ('clothing', 0.3664591084764433), ('artificial physical object', 0.3635756705746942), ('artificial entity', 0.281801743746239)]
#
# Topic 16: [('computer algebra system', 0.6875477108291809), ('Reduce', 0.23302465839463676), ('symbolic equation solving', 0.17562090916463918), ('Category:Computer algebra systems', 0.17562090916463913)]
#
# Topic 17: [('intentional human action', 0.6815071102977953), ('use', 0.2575126848154599), ('process', 0.21331280823949428), ('law', 0.21331280823949428)]
#
# Topic 18: [('Earth', 0.7018088237093725), ('Wikidata Sandbox', 0.18514974405372306), ('Category:Earth', 0.1648551479313434), ('geophysics', 0.1648551479313434)]
#
# Topic 19: [('archaeological site', 0.6067712472581773), ('Susa', 0.41171262503724865), ('human-geographic territorial entity', 0.23870526135058062), ('landmark', 0.20834191851754452)]
#
# Topic 20: [('minute', 0.4610852668276838), ('hour', 0.40950288026938236), ('second', 0.3616872841865816), ('unit of time', 0.33663880909950683)]
#
# Topic 21: [('mathematics', 0.6678956841734643), ('area of mathematics', 0.29158916915033656), ('geometry', 0.21361507290821607), ('set theory', 0.14197774344473305)]
#
# Topic 22: [('Wikidata', 0.5536513330664732), ('knowledge base', 0.32880543232454545), ('MediaWiki encyclopedia', 0.23735289899660436), ('knowledge graph', 0.23526207016541065)]
#
# Topic 23: [('building', 0.558418520623365), ('library', 0.40573450261591976), ('facility', 0.2604866615721934), ('library science', 0.22041706674722364)]
#
# Topic 24: [('DNA', 0.5237994241450777), ('nucleotides', 0.33130602136257586), ('nucleic acid', 0.2638813558994355), ('polynucleotide', 0.2622650713183715)]
#
# Topic 25: [('operation', 0.49080027192799547), ('goods', 0.4567619020137969), ('factory', 0.3470385827962465), ('economics term', 0.27304183708846547)]
#
# Topic 26: [('economics', 0.47217151378539673), ('service', 0.39676222425470076), ('business', 0.3723504771234585), ('economic sector', 0.3088247047798862)]
#
# Topic 27: [('property', 0.6163294469228031), ('quality', 0.4559848027642951), ('philosophical concept', 0.2900960518449255), ('category of being', 0.256393476167046)]
#
# Topic 28: [('work', 0.3583827935939598), ('document', 0.34860921516485066), ('banknote', 0.3194066534496502), ('communication medium', 0.2800315791100927)]
#
# Topic 29: [('scholarly article', 0.6015009550075459), ('Utility library for structural bioinformatics.', 0.3783201427032318), ('bioinformatics', 0.3717480344601842), ('scholarly publication', 0.23381470681930816)]
#
# Topic 30: [('music', 0.4648193982721099), ('musicology', 0.38466358346303925), ('art', 0.37600301482959647), ('music theory', 0.34584921458335627)]
#
# Topic 31: [('build automation', 0.4440010887550601), ('software build', 0.3701749909041983), ('codec', 0.3588723443912617), ('CMake', 0.29729986423088345)]
#
# Topic 32: [('simulation', 0.6291741517773314), ('software', 0.29653124647742973), ('simulator', 0.29408100605729465), ('computational science', 0.17680620290373988)]
#
# Topic 33: [('widget toolkit', 0.5158551273540184), ('graphics library', 0.4487459573070169), ('software category', 0.41504090420047085), ('graphical user interface', 0.29524287708530383)]
#
# Topic 34: [('piping', 0.6098375855648243), ('pipeline', 0.34792307237542697), ('pipeline transport', 0.3422757955363537), ('Category:Pipelines', 0.23043832307549986)]
#
# Topic 35: [('protein', 0.5456226473536391), ('biological process', 0.3593630479717306), ('establishment of protein localization to spindle pole body', 0.17928551623561687), ('regulation protein catabolic process at synapse', 0.17490279710132375)]
#
# Topic 36: [('textile', 0.5364711167469377), ('clothing', 0.37529492548018906), ('artificial physical object', 0.3441061734989274), ('artificial entity', 0.2919275116262337)]
#
# Topic 37: [('integrated development environment', 0.49888336904281066), ('text editor', 0.43765611949740385), ('source code editor', 0.3562251065129582), ('Vim', 0.3532885410641429)]
#
# Topic 38: [('workflow', 0.5451686533723177), ('activity', 0.34097643974399044), ('work-study', 0.30818189202168134), ('business process', 0.3012708714373005)]
#
# Topic 39: [('cell', 0.5000183314360094), ('tissue', 0.4582216878083059), ('multicellular structure', 0.3448698727111583), ('group of cells', 0.31549630538086376)]
#
# Topic 40: [('document', 0.591438128450189), ('technical standard', 0.3795024446214698), ('specification', 0.3660095050224238), ('text', 0.22541136571280315)]
#
# Topic 41: [('film', 0.7042495846821473), ('Spotlight', 0.2045326702077733), ('audiovisual work', 0.18761540013139094), ('title sequence', 0.18761540013139077)]
#
# Topic 42: [('Protein kinase, ATP binding site', 0.5104671066169698), ('Protein kinase domain', 0.5061555501482233), ('Hippo Dmel_CG11228', 0.11715645721250387), ('FGR proto-oncogene, Src family tyrosine kinase', 0.09923457361945508)]
#
# Topic 43: [('applied mathematics', 0.3249110337151671), ('computer science', 0.3175651528706739), ('data science', 0.2880073637717194), ('academic major', 0.2727264283124097)]
#
# Topic 44: [('minute', 0.46108526682768397), ('hour', 0.40950288026938214), ('second', 0.36168728418658186), ('unit of time', 0.33663880909950655)]
#
# Topic 45: [('protein', 0.5288116797215604), ('biological process', 0.37965113609769324), ('establishment of protein localization to spindle pole body', 0.18608900466442665), ('regulation protein catabolic process at synapse', 0.1812895676467884)]
#
# Topic 46: [('goods', 0.5942268007412872), ('property', 0.38243139631876444), ('entity', 0.33668793871549735), ('economic concept', 0.21280716929465618)]
#
# Topic 47: [('graffiti', 0.5313388991933177), ('work', 0.3985019207348143), ('art genre', 0.39172223867624184), ('street art', 0.3575970304392281)]
#
# Topic 48: [('film', 0.6978902657667582), ('trailer', 0.22177094554467455), ('credit', 0.19243491331907064), ('moving image', 0.19243491331907062)]
#
# Topic 49: [('messenger RNA', 0.6064816810372747), ('codon', 0.4140256156499676), ('standard genetic code', 0.21380371171533163), ('transcript', 0.19010280118191142)]
#
# Topic 50: [('software library', 0.5563558860348173), ('JavaScript library', 0.46388774290040935), ('jQuery', 0.43045323160010407), ('software category', 0.32443807780713213)]
#
#
# Algorithm: Closeness centrality
# Topic 0: [('database', 0.35714285714285715), ('work', 0.33613445378151263), ('index', 0.31496062992125984), ('construction', 0.3125)]
#
# Topic 1: [('library science', 0.34375), ('document', 0.3313253012048193), ('life sciences', 0.2894736842105263), ('text', 0.2722772277227723)]
#
# Topic 2: [('software', 0.31901840490797545), ('application', 0.30057803468208094), ('computer program', 0.27956989247311825), ('software category', 0.2708333333333333)]
#
# Topic 3: [('protein', 0.625), ('first-order metaclass', 0.5), ('Probable ABC transporter ATP-binding protein MlaF/Mkl', 0.4326923076923077), ('protein catabolic process, modulating synaptic transmission', 0.3879310344827586)]
#
# Topic 4: [('concept', 0.6), ('abstract object', 0.5), ('variable-order metaclass', 0.4838709677419355), ('mental representation', 0.45454545454545453)]
#
# Topic 5: [('algorithm', 0.2996742671009772), ('mathematics', 0.2948717948717949), ('algorithmics', 0.2920634920634921), ('computer science', 0.2787878787878788)]
#
# Topic 6: [('cosmology', 0.39644970414201186), ('universe', 0.37640449438202245), ('observable universe', 0.3544973544973545), ('logic', 0.3175355450236967)]
#
# Topic 7: [('system', 0.3767123287671233), ('structure', 0.34375), ('abstract object', 0.3125), ('construction', 0.3055555555555556)]
#
# Topic 8: [('function', 0.5757575757575758), ('functor', 0.5428571428571428), ('category theory', 0.4634146341463415), ('mathematical concept', 0.37254901960784315)]
#
# Topic 9: [('music', 0.23201438848920863), ('specialty', 0.21864406779661016), ('aspect of music', 0.21717171717171718), ('first-order metaclass', 0.20411392405063292)]
#
# Topic 10: [('catalogue', 0.373134328358209), ('list', 0.36496350364963503), ('information', 0.352112676056338), ('knowledge organization system', 0.31446540880503143)]
#
# Topic 11: [('mathematics', 0.582089552238806), ('function', 0.5735294117647058), ('mathematical concept', 0.46987951807228917), ('binary relation', 0.40625)]
#
# Topic 12: [('Cornell University', 0.6666666666666666), ('private university', 0.5), ('land-grant university', 0.4666666666666667), ('private not-for-profit educational institution', 0.4666666666666667)]
#
# Topic 13: [('virtuoso', 0.5652173913043478), ('music interpreter', 0.48148148148148145), ('occupation', 0.48148148148148145), ('instrumentalist', 0.4482758620689655)]
#
# Topic 14: [('HyperText Markup Language', 0.38095238095238093), ('W3C Recommendation', 0.37037037037037035), ('technical standard', 0.3669724770642202), ('creative work', 0.3389830508474576)]
#
# Topic 15: [('textile', 0.2611464968152866), ('clothing', 0.25), ('artificial physical object', 0.24898785425101214), ('artificial entity', 0.23976608187134502)]
#
# Topic 16: [('Reduce', 0.5263157894736842), ('computer algebra system', 0.5172413793103449), ('science', 0.4411764705882353), ('free software', 0.38461538461538464)]
#
# Topic 17: [('property', 0.32926829268292684), ('entity', 0.32142857142857145), ('converter', 0.3068181818181818), ('use', 0.3068181818181818)]
#
# Topic 18: [('Earth', 0.5957446808510638), ('Wikidata Sandbox', 0.5185185185185185), ('book', 0.4444444444444444), ('mantle', 0.3783783783783784)]
#
# Topic 19: [('Susa', 0.5714285714285714), ('archaeological site', 0.5106382978723404), ('ancient city', 0.4067796610169492), ('capital', 0.4067796610169492)]
#
# Topic 20: [('minute', 0.5897435897435898), ('second', 0.5476190476190477), ('hour', 0.5111111111111111), ('time interval', 0.5111111111111111)]
#
# Topic 21: [('mathematics', 0.45054945054945056), ('materials science', 0.4019607843137255), ('area of mathematics', 0.3942307692307692), ('branch of science', 0.36607142857142855)]
#
# Topic 22: [('Wikidata', 0.5350877192982456), ('knowledge base', 0.40939597315436244), ('Linked Open Data cloud diagram', 0.3860759493670886), ('semantic wiki', 0.38125)]
#
# Topic 23: [('library science', 0.3175182481751825), ('library', 0.30633802816901406), ('document', 0.28431372549019607), ('building', 0.257396449704142)]
#
# Topic 24: [('DNA', 0.5662650602409639), ('nucleotides', 0.44549763033175355), ('polynucleotide', 0.4392523364485981), ('nucleic acid', 0.4253393665158371)]
#
# Topic 25: [('operation', 0.42168674698795183), ('factory', 0.42168674698795183), ('goods', 0.3723404255319149), ('economics term', 0.3333333333333333)]
#
# Topic 26: [('service', 0.5473684210526316), ('economics', 0.47706422018348627), ('business', 0.45614035087719296), ('economic sector', 0.4369747899159664)]
#
# Topic 27: [('quality', 0.6), ('property', 0.6), ('philosophical concept', 0.47368421052631576), ('Category:Qualities', 0.391304347826087)]
#
# Topic 28: [('work', 0.29411764705882354), ('intellectual work', 0.2926829268292683), ('written work', 0.2857142857142857), ('document', 0.2803738317757009)]
#
# Topic 29: [('scholarly article', 0.55), ('Utility library for structural bioinformatics.', 0.55), ('bioinformatics', 0.5), ('Dataset Descriptions for Linked Data Systems', 0.36666666666666664)]
#
# Topic 30: [('music', 0.41911764705882354), ('specialty', 0.3475609756097561), ('art', 0.3313953488372093), ('musicology', 0.3220338983050847)]
#
# Topic 31: [('codec', 0.3490566037735849), ('software category', 0.32456140350877194), ('software feature', 0.32456140350877194), ('build automation', 0.30327868852459017)]
#
# Topic 32: [('software', 0.3956043956043956), ('simulator', 0.391304347826087), ('simulation', 0.34285714285714286), ('computer program', 0.3333333333333333)]
#
# Topic 33: [('widget toolkit', 0.4339622641509434), ('software category', 0.41818181818181815), ('graphics library', 0.38333333333333336), ('class', 0.35384615384615387)]
#
# Topic 34: [('pipeline transport', 0.384), ('pipeline', 0.35294117647058826), ('economic branch', 0.35294117647058826), ('piping', 0.35294117647058826)]
#
# Topic 35: [('protein', 0.38317757009345793), ('first-order metaclass', 0.33064516129032256), ('biopolymer', 0.31297709923664124), ('amino acid', 0.3031423290203327)]
#
# Topic 36: [('textile', 0.3192771084337349), ('product', 0.29444444444444445), ('object', 0.2676767676767677), ('clothing', 0.263681592039801)]
#
# Topic 37: [('software', 0.34782608695652173), ('economic branch', 0.3310344827586207), ('Vim', 0.3221476510067114), ('lighting', 0.3116883116883117)]
#
# Topic 38: [('work', 0.29375), ('activity', 0.29012345679012347), ('workflow', 0.27325581395348836), ('entity', 0.27011494252873564)]
#
# Topic 39: [('cell', 0.40476190476190477), ('unit', 0.35789473684210527), ('tissue', 0.3300970873786408), ('biological component', 0.3177570093457944)]
#
# Topic 40: [('document', 0.45161290322580644), ('text', 0.39436619718309857), ('specification', 0.39436619718309857), ('technical standard', 0.37333333333333335)]
#
# Topic 41: [('film', 0.7727272727272727), ('Spotlight', 0.53125), ('series', 0.4473684210526316), ('title sequence', 0.4473684210526316)]
#
# Topic 42: [('Protein kinase, ATP binding site', 0.573394495412844), ('Protein kinase domain', 0.5707762557077626), ('Hippo Dmel_CG11228', 0.5208333333333334), ('Protein kinase, ATP binding site, protein family', 0.4180602006688963)]
#
# Topic 43: [('artificial intelligence', 0.25726744186046513), ('computer science', 0.2388663967611336), ('machine learning', 0.23197903014416776), ('artificial entity', 0.23167539267015708)]
#
# Topic 44: [('minute', 0.5897435897435898), ('second', 0.5476190476190477), ('time interval', 0.5111111111111111), ('hour', 0.5111111111111111)]
#
# Topic 45: [('protein', 0.37037037037037035), ('first-order metaclass', 0.3418803418803419), ('biopolymer', 0.3137254901960784), ('taxon', 0.30710172744721687)]
#
# Topic 46: [('property', 0.5), ('entity', 0.48484848484848486), ('goods', 0.45714285714285713), ('disposition', 0.38095238095238093)]
#
# Topic 47: [('graffiti', 0.5882352941176471), ('work', 0.4878048780487805), ('art genre', 0.45454545454545453), ('street art', 0.4444444444444444)]
#
# Topic 48: [('information', 0.26548672566371684), ('data', 0.2553191489361702), ('secondary information', 0.2510460251046025), ('metadata', 0.24193548387096775)]
#
# Topic 49: [('codon', 0.5094339622641509), ('messenger RNA', 0.42857142857142855), ('start codon', 0.40298507462686567), ('standard genetic code', 0.38028169014084506)]
#
# Topic 50: [('jQuery', 0.6), ('software library', 0.5714285714285714), ('JavaScript library', 0.5217391304347826), ('project', 0.48)]
#
#
# Algorithm: Betweenness centrality
# Topic 0: [('database', 0.7153846153846154), ('construction', 0.5692307692307692), ('work', 0.49230769230769234), ('index', 0.4198717948717949)]
#
# Topic 1: [('library science', 0.6565656565656566), ('document', 0.6090909090909091), ('life sciences', 0.5050505050505051), ('BioHackathon series in 2011 and 2012: penetration of ontology and linked data in life science domains', 0.43434343434343436)]
#
# Topic 2: [('software', 0.6225490196078431), ('application', 0.4743589743589744), ('software category', 0.4562594268476622), ('biology', 0.4364630467571645)]
#
# Topic 3: [('protein', 0.897979797979798), ('first-order metaclass', 0.36262626262626263), ('type of statistic', 0.24141414141414141), ('protein family', 0.21616161616161617)]
#
# Topic 4: [('concept', 0.7142857142857143), ('abstract object', 0.37142857142857144), ('mental representation', 0.37142857142857144), ('capability', 0.2571428571428572)]
#
# Topic 5: [('algorithm', 0.4602768866744026), ('algorithmics', 0.3906365890837941), ('mathematics', 0.38289195276772914), ('engineering', 0.2955315905626465)]
#
# Topic 6: [('cosmology', 0.5763606211367405), ('logic', 0.5477159656264133), ('universe', 0.4877129503995175), ('observable universe', 0.3083069500979948)]
#
# Topic 7: [('system', 0.7717171717171718), ('structure', 0.49629629629629635), ('construction', 0.4575757575757576), ('abstract object', 0.3730639730639731)]
#
# Topic 8: [('function', 0.7894736842105263), ('functor', 0.5555555555555556), ('category theory', 0.5438596491228069), ('mathematical concept', 0.0)]
#
# Topic 9: [('music', 0.7022468507751939), ('protein', 0.5388808139534884), ('specialty', 0.4831637596899225), ('music genre', 0.462390988372093)]
#
# Topic 10: [('catalogue', 0.5535102040816329), ('information', 0.44444897959183677), ('list', 0.36326530612244906), ('knowledge organization system', 0.2420816326530612)]
#
# Topic 11: [('mathematics', 0.7024291497975709), ('function', 0.6052631578947368), ('binary relation', 0.15182186234817813), ('arity', 0.11133603238866396)]
#
# Topic 12: [('Cornell University', 0.7802197802197803), ('private university', 0.26373626373626374), ('land-grant university', 0.20329670329670332), ('private not-for-profit educational institution', 0.19047619047619047)]
#
# Topic 13: [('virtuoso', 0.5897435897435898), ('occupation', 0.5384615384615384), ('music interpreter', 0.4615384615384615), ('instrumentalist', 0.3333333333333333)]
#
# Topic 14: [('HyperText Markup Language', 0.6205128205128205), ('technical standard', 0.41217948717948716), ('W3C Recommendation', 0.37115384615384617), ('document', 0.3230769230769231)]
#
# Topic 15: [('textile', 0.47212226220622866), ('clothing', 0.4495757252654492), ('architectural structure', 0.37744902039184325), ('work', 0.3718512594962015)]
#
# Topic 16: [('computer algebra system', 0.7241379310344828), ('Reduce', 0.632183908045977), ('science', 0.5172413793103449), ('free software', 0.25287356321839083)]
#
# Topic 17: [('property', 0.6210826210826211), ('intentional human action', 0.5641025641025641), ('converter', 0.5555555555555556), ('entity', 0.5128205128205129)]
#
# Topic 18: [('Earth', 0.8544973544973544), ('book', 0.5476190476190476), ('Wikidata Sandbox', 0.47619047619047616), ('mantle', 0.0)]
#
# Topic 19: [('Susa', 0.7391304347826088), ('archaeological site', 0.588768115942029), ('ancient city', 0.2391304347826087), ('capital', 0.2391304347826087)]
#
# Topic 20: [('second', 0.47524938829286667), ('minute', 0.3308865047995483), ('time interval', 0.2766798418972332), ('hour', 0.2478825522303783)]
#
# Topic 21: [('mathematics', 0.6776422764227643), ('materials science', 0.5493902439024391), ('base material', 0.38170731707317074), ('area of mathematics', 0.1949186991869918)]
#
# Topic 22: [('Wikidata', 0.8126593806921675), ('knowledge base', 0.25646630236794177), ('Linked Open Data cloud diagram', 0.24699453551912567), ('Semantic Web', 0.1996357012750456)]
#
# Topic 23: [('library science', 0.686180165731088), ('library', 0.6182838813151563), ('reference work', 0.4812884255546645), ('document', 0.4330392943063352)]
#
# Topic 24: [('DNA', 0.7461469534050177), ('nucleotides', 0.3129718599862732), ('mitochondrion', 0.16591931670860996), ('genome', 0.15438496148859904)]
#
# Topic 25: [('factory', 0.6369747899159665), ('operation', 0.5932773109243697), ('goods', 0.5109243697478992), ('property', 0.25882352941176473)]
#
# Topic 26: [('service', 0.5764203117144291), ('economics', 0.4250879839115133), ('quaternary sector of the economy', 0.31900452488687786), ('business', 0.2356711915535447)]
#
# Topic 27: [('property', 0.7222222222222222), ('quality', 0.6388888888888888), ('philosophical concept', 0.41666666666666663), ('Category:Qualities', 0.0)]
#
# Topic 28: [('work', 0.39281746031746034), ('intellectual work', 0.3706395891690009), ('document', 0.32592903828197967), ('banknote', 0.28088935574229706)]
#
# Topic 29: [('scholarly article', 0.7272727272727273), ('bioinformatics', 0.6181818181818182), ('Utility library for structural bioinformatics.', 0.5454545454545454), ('Dataset Descriptions for Linked Data Systems', 0.0)]
#
# Topic 30: [('music', 0.7955827067669174), ('specialty', 0.39974937343358397), ('first-order metaclass', 0.29448621553884713), ('art', 0.28634085213032584)]
#
# Topic 31: [('codec', 0.710960960960961), ('build automation', 0.5037537537537538), ('system', 0.39039039039039036), ('decoder', 0.3783783783783784)]
#
# Topic 32: [('software', 0.6857142857142857), ('simulator', 0.6079365079365079), ('simulation', 0.5238095238095238), ('computer program', 0.38571428571428573)]
#
# Topic 33: [('widget toolkit', 0.6284584980237153), ('software category', 0.5019762845849802), ('class', 0.40316205533596833), ('taxon', 0.3913043478260869)]
#
# Topic 34: [('pipeline transport', 0.5746158392434989), ('software', 0.5412234042553191), ('economic branch', 0.4787234042553191), ('piping', 0.420065011820331)]
#
# Topic 35: [('protein', 0.7881978027459098), ('first-order metaclass', 0.3734783708485641), ('type of map', 0.36188837348496183), ('geographic map', 0.3399670806524016)]
#
# Topic 36: [('textile', 0.7596758587324626), ('product', 0.4818577648766328), ('abstract object', 0.46008708272859217), ('object', 0.444121915820029)]
#
# Topic 37: [('software', 0.6506575059101655), ('lighting', 0.5336879432624113), ('economic branch', 0.49645390070921985), ('Vim', 0.45981087470449156)]
#
# Topic 38: [('work', 0.6345975948196115), ('workflow', 0.5596669750231268), ('activity', 0.5467160037002775), ('converter', 0.46901017576318227)]
#
# Topic 39: [('cell', 0.7295008912655971), ('unit', 0.4688057040998217), ('abstract object', 0.40106951871657753), ('information', 0.3939393939393939)]
#
# Topic 40: [('document', 0.7063492063492063), ('character', 0.48148148148148145), ('text', 0.45238095238095233), ('specification', 0.4206349206349206)]
#
# Topic 41: [('film', 0.9558823529411764), ('Spotlight', 0.3088235294117647), ('Sexual abuse scandal in the Catholic archdiocese of Boston', 0.22794117647058823), ('series', 0.0)]
#
# Topic 42: [('Protein kinase, ATP binding site', 0.46029032258064506), ('Protein kinase domain', 0.44837275985663066), ('Hippo Dmel_CG11228', 0.43698463901689827), ('protein', 0.436)]
#
# Topic 43: [('artificial intelligence', 0.5418270171448141), ('device', 0.3753155037053344), ('artificial entity', 0.3609718553574488), ('tool', 0.3504108885464818)]
#
# Topic 44: [('second', 0.4752493882928664), ('minute', 0.3308865047995483), ('time interval', 0.27667984189723316), ('hour', 0.24788255223037833)]
#
# Topic 45: [('protein', 0.73253144654088), ('first-order metaclass', 0.46181865828092244), ('taxon', 0.45522798742138404), ('plant', 0.4367793501048215)]
#
# Topic 46: [('entity', 0.65), ('goods', 0.625), ('property', 0.5916666666666667), ('disposition', 0.35)]
#
# Topic 47: [('graffiti', 0.7578947368421053), ('work', 0.5210526315789473), ('art genre', 0.28421052631578947), ('street art', 0.19473684210526315)]
#
# Topic 48: [('information', 0.6480225988700565), ('metadata', 0.5050847457627119), ('advertising', 0.46214689265536724), ('artificial entity', 0.4062146892655367)]
#
# Topic 49: [('codon', 0.7891737891737892), ('messenger RNA', 0.5128205128205129), ('start codon', 0.3817663817663818), ('standard genetic code', 0.2792022792022792)]
#
# Topic 50: [('jQuery', 0.5909090909090909), ('software library', 0.5), ('project', 0.4545454545454546), ('JavaScript library', 0.21212121212121213)]
#
#
# Algorithm: Communicability betweenness centrality
# Topic 0: [('database', 0.7244654605944721), ('construction', 0.5724281971796762), ('work', 0.508243348161075), ('index', 0.4417445201075427)]
#
# Topic 1: [('library science', 0.6634714603763229), ('document', 0.6288511991749709), ('life sciences', 0.5090541726339515), ('BioHackathon series in 2011 and 2012: penetration of ontology and linked data in life science domains', 0.4396384098187511)]
#
# Topic 2: [('software', 0.6469866506372794), ('application', 0.5049832253970399), ('software category', 0.4604334363217811), ('biology', 0.45582402516060994)]
#
# Topic 3: [('protein', 0.9082605283457162), ('first-order metaclass', 0.40425666678082883), ('type of statistic', 0.2480497165897224), ('protein family', 0.2305518007739436)]
#
# Topic 4: [('concept', 0.7752857657498203), ('abstract object', 0.46782538014128705), ('variable-order metaclass', 0.3961458894054767), ('mental representation', 0.39346531343788416)]
#
# Topic 5: [('algorithm', 0.48458268525315473), ('mathematics', 0.4132272751059948), ('algorithmics', 0.40408605190582125), ('engineering', 0.305261299905545)]
#
# Topic 6: [('cosmology', 0.6396168661005198), ('logic', 0.5489708893576958), ('universe', 0.5488371775064588), ('observable universe', 0.38303099795655565)]
#
# Topic 7: [('system', 0.7827198069059921), ('structure', 0.5091588948805695), ('construction', 0.47205604134809054), ('abstract object', 0.39002818237641523)]
#
# Topic 8: [('function', 0.7968233594810357), ('functor', 0.5920923046397615), ('category theory', 0.5525393266925617), ('mathematical concept', 0.040230048789246166)]
#
# Topic 9: [('music', 0.7077198661947863), ('protein', 0.5410633510922539), ('specialty', 0.4878391707958208), ('music genre', 0.46354086969687686)]
#
# Topic 10: [('catalogue', 0.5850362456382343), ('information', 0.46114534185915457), ('list', 0.3757694442685125), ('knowledge organization system', 0.2665353898988819)]
#
# Topic 11: [('mathematics', 0.7533014307427334), ('function', 0.6773285035148111), ('mathematical concept', 0.22397365919776552), ('binary relation', 0.21923656357598942)]
#
# Topic 12: [('Cornell University', 0.8292187864084543), ('private university', 0.33587845674250366), ('land-grant university', 0.25426367487956647), ('private not-for-profit educational institution', 0.24751763065275917)]
#
# Topic 13: [('virtuoso', 0.6391677613037129), ('occupation', 0.5511243679913025), ('music interpreter', 0.5001135842692994), ('instrumentalist', 0.376905415511939)]
#
# Topic 14: [('HyperText Markup Language', 0.6348064499428706), ('technical standard', 0.4402574239246736), ('W3C Recommendation', 0.37508908667921087), ('document', 0.36024643830155395)]
#
# Topic 15: [('textile', 0.5148325475495424), ('clothing', 0.47835297145905736), ('architectural structure', 0.37842626025300424), ('work', 0.37488147599961474)]
#
# Topic 16: [('computer algebra system', 0.7321604898009394), ('Reduce', 0.6606256294921221), ('science', 0.5264714199733403), ('free software', 0.26612402193193896)]
#
# Topic 17: [('property', 0.6250346613136293), ('intentional human action', 0.5665072553859877), ('converter', 0.5608172478371969), ('entity', 0.523598283125432)]
#
# Topic 18: [('Earth', 0.8572567557162291), ('book', 0.5508193563648662), ('Wikidata Sandbox', 0.5132393043057862), ('mantle', 0.04101768280216127)]
#
# Topic 19: [('Susa', 0.7698824516224178), ('archaeological site', 0.619390728974077), ('ancient city', 0.2623679945034668), ('capital', 0.26236799450346654)]
#
# Topic 20: [('minute', 0.5639578854801078), ('second', 0.5598284998845621), ('hour', 0.4553687938029857), ('time interval', 0.4110796494181059)]
#
# Topic 21: [('mathematics', 0.7148868858517909), ('materials science', 0.5608632668465237), ('base material', 0.39099419145506886), ('area of mathematics', 0.35375602251632515)]
#
# Topic 22: [('Wikidata', 0.8487242822661123), ('knowledge base', 0.3203613297810263), ('Linked Open Data cloud diagram', 0.26935475742821824), ('Semantic Web', 0.22749690237614506)]
#
# Topic 23: [('library science', 0.691962425977103), ('library', 0.6365391824804817), ('reference work', 0.4828396652132114), ('document', 0.4419078998935966)]
#
# Topic 24: [('DNA', 0.8524274823423242), ('nucleotides', 0.41765931179312715), ('polynucleotide', 0.2817988474447526), ('nucleic acid', 0.255839027558381)]
#
# Topic 25: [('factory', 0.6570751413332148), ('operation', 0.6247928522350035), ('goods', 0.5331500359838542), ('property', 0.27030773394567187)]
#
# Topic 26: [('service', 0.6636281436451598), ('economics', 0.5208861304371948), ('business', 0.3861717135343531), ('quaternary sector of the economy', 0.3604775562672341)]
#
# Topic 27: [('property', 0.7401289831192279), ('quality', 0.6771680507456987), ('philosophical concept', 0.43934307684229396), ('philosophy', 0.04468554039715456)]
#
# Topic 28: [('work', 0.4336959257695837), ('intellectual work', 0.384688374144002), ('document', 0.37835828412724826), ('banknote', 0.3101410411504921)]
#
# Topic 29: [('scholarly article', 0.7357181548271228), ('bioinformatics', 0.627508419747609), ('Utility library for structural bioinformatics.', 0.5881799498432276), ('scholarly work', 0.04045353916865862)]
#
# Topic 30: [('music', 0.8198737964148001), ('specialty', 0.41485834299802266), ('art', 0.3200668747403146), ('first-order metaclass', 0.29962878797114684)]
#
# Topic 31: [('codec', 0.7184378473102631), ('build automation', 0.5253289401867215), ('decoder', 0.39269859125070206), ('system', 0.39231357661789235)]
#
# Topic 32: [('software', 0.6923846452671091), ('simulator', 0.6272824045183992), ('simulation', 0.5306677847226858), ('computer program', 0.40172819790890785)]
#
# Topic 33: [('widget toolkit', 0.677824516535547), ('software category', 0.5630449747882551), ('class', 0.41528999301417524), ('taxon', 0.3951318797386242)]
#
# Topic 34: [('pipeline transport', 0.6221263890137486), ('software', 0.555656170886864), ('economic branch', 0.48917451602766626), ('piping', 0.48073319463624115)]
#
# Topic 35: [('protein', 0.8493737614916952), ('first-order metaclass', 0.4031572895481123), ('type of map', 0.3635077122198625), ('geographic map', 0.34164186362214355)]
#
# Topic 36: [('textile', 0.785495507015111), ('product', 0.4943425638025944), ('abstract object', 0.4615023954033148), ('object', 0.44768991545210146)]
#
# Topic 37: [('software', 0.6565375562200749), ('lighting', 0.5524521255385423), ('economic branch', 0.5063565089136803), ('Vim', 0.5039121695269523)]
#
# Topic 38: [('work', 0.6386079693944929), ('workflow', 0.580092684008251), ('activity', 0.5663112787998895), ('converter', 0.4714266238912562)]
#
# Topic 39: [('cell', 0.7814684144220508), ('unit', 0.4826982786432477), ('abstract object', 0.40654973489428453), ('information', 0.3970183460295913)]
#
# Topic 40: [('document', 0.7399988760428035), ('character', 0.48986013903339026), ('specification', 0.4826677581364379), ('text', 0.4729330001385533)]
#
# Topic 41: [('film', 0.9589954308494726), ('Spotlight', 0.359951334318205), ('Sexual abuse scandal in the Catholic archdiocese of Boston', 0.2343825398688431), ('Category:Film', 0.05793635723582401)]
#
# Topic 42: [('Protein kinase, ATP binding site', 0.8394655487076153), ('Protein kinase domain', 0.8386419756111018), ('Hippo Dmel_CG11228', 0.49797749359350324), ('protein', 0.4373409665319631)]
#
# Topic 43: [('artificial intelligence', 0.5492727956226808), ('device', 0.37808972684581693), ('tool', 0.35526521196738026), ('artificial entity', 0.3544811786678855)]
#
# Topic 44: [('minute', 0.5639578854801073), ('second', 0.5598284998845618), ('hour', 0.45536879380298545), ('time interval', 0.4110796494181055)]
#
# Topic 45: [('protein', 0.7864913262713285), ('first-order metaclass', 0.4850958176702402), ('taxon', 0.4588104614073643), ('plant', 0.4458720645641105)]
#
# Topic 46: [('entity', 0.6647442583019739), ('goods', 0.6346405018763654), ('property', 0.6208828892984338), ('disposition', 0.3687887313490892)]
#
# Topic 47: [('graffiti', 0.8012581460574135), ('work', 0.5414786527520781), ('art genre', 0.3688458349382116), ('street art', 0.296695568497784)]
#
# Topic 48: [('information', 0.6557534781851806), ('metadata', 0.5129839911737819), ('advertising', 0.4668428201545561), ('artificial entity', 0.4103100337407898)]
#
# Topic 49: [('codon', 0.8066248334120028), ('messenger RNA', 0.5300437938405315), ('start codon', 0.4023781027170117), ('standard genetic code', 0.2998232058854143)]
#
# Topic 50: [('jQuery', 0.66979428595378), ('software library', 0.6131425457727955), ('project', 0.47115258031668394), ('JavaScript library', 0.3936276586008213)]

# %% [markdown]
# ## Add labels to LDA model
# Finally, we will be saving the best results to our LDA model that has been trained previously. Now, when we load the model again, after a topic has been inferred for a given text we will also be able to return a representative label for the topic, which will be also linked to Wikidata:

# %%
from herc_common.topic import Topic

final_results = [get_centrality_algorithm_results(g,
                                                 nxa.centrality.information_centrality,
                                                ['Q4167836', 'Q11862829'], top_n=1)
                 for g in connected_topic_subgraphs]

final_results_topics = [Topic.from_node(topic[0], topic[1], "lda") 
                        for result in final_results for topic in result]
lda_model = lda_pipe.named_steps['model']

# %%
from tqdm import tqdm

import en_core_web_md
import string
import numpy as np

en_core_web_md.load()

# %%
from herc_common.topic import LabelledTopicModel

labelled_topic_model = LabelledTopicModel(lda_model, final_results_topics)

lda_pipe.steps.pop()
lda_pipe.steps.append(('model', labelled_topic_model))

# %%
from herc_common.utils import save_object

save_object(lda_pipe, os.path.join(NOTEBOOK_3_RESULTS_DIR, 'lda_pipe_with_labels.pkl'))

# %% [markdown]
# ## Obtaining the results for every article in the dataset

# %%
import en_core_sci_lg

en_core_sci_lg.load()

# %%
results = lda_pipe.transform(git_repositories)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %% [markdown]
# ## Saving the results

# %%
NEW_COL_NAME = 'topics_from_lda'

git_df[NEW_COL_NAME] = ['\n'.join([f"{topic.label}, {topic.score:.5f}" for topic in result])
                        for result in results]

results_df = git_df[['gh_id', 'name', NEW_COL_NAME]]
results_df.head()
# Out:
#        gh_id                   name  \
# 0  216602979                LIRICAL
# 1  199330464   wikidata_ontomatcher
# 2  253207181          ro-crate-ruby
# 3  212556220  Misc_Training_scripts
# 4  155879756              FAIRifier
#
#                                      topics_from_lda
# 0  Protein kinase domain, 0.12012\ncodon, 0.00000...
# 1  Wikidata, 0.03981\ncodon, 0.00000\nUtility lib...
# 2  information, 0.08174\ndata science, 0.00000\ng...
# 3  virtuoso, 0.04775\nvirtuoso, 0.02404\ndocument...
# 4  database, 0.13379\ntextile, 0.00004\nHyperText...

# %%
OUTPUT_FILE_NAME = "git_df_with_lda_topics.csv"

results_df.to_csv(os.path.join(NOTEBOOK_3_RESULTS_DIR, OUTPUT_FILE_NAME), index=False)

# %%
results_df
# Out:
#         gh_id                                  name  \
# 0   216602979                               LIRICAL
# 1   199330464                  wikidata_ontomatcher
# 2   253207181                         ro-crate-ruby
# 3   212556220                 Misc_Training_scripts
# 4   155879756                             FAIRifier
# 5    90349931                                  elda
# 6   126633812            music-genre-classification
# 7   173520377                     probabilistic_nlg
# 8   103798851         DataStructures-Algorithms-InC
# 9   153249816  Music-Generation-Using-Deep-Learning
# 10  170129937                             evaluomeR
# 11   57412597                          hemodonacion
# 12   46532803                           DnaCompress
# 13   95547920                      trackhub-creator
# 14   94098106                               libpogo
# 15   83849237                                 vimrc
# 16   83414669                        cpp-playground
# 17   56680034                          genenetwork2
# 18  231038084                                  MPCC
# 19   14387064                         pubannotation
# 20  212904362                               UniMath
# 21  113264497                     neo4j-to-reasoner
# 22  260889871                           dl-reasoner
# 23  161862375                             biohack18
# 24  171842501                      biosample_jsonld
# 25  257154635                     bh20-seq-resource
# 26  260966843                                  odgi
# 27  257545116                               arvados
# 28  150747903                       termite_toolkit
# 29  151696606                    JavaTermiteStarter
# 30  126086017                               cwltool
# 31  150911020                          cwl-tes-temp
# 32   83817036                              mmtf-cpp
# 33  254755549    covid-19-Annotations-on-Structures
# 34    3103186                               php-lib
# 35    3103225                       bio2rdf-scripts
# 36   22713247                                  aida
# 37   21820701                             memetools
# 38   34799405                                owlapi
# 39   42526998                  pythonontologysearch
# 40  238953196                         my-react-form
# 41  157134523            python-ecology-lesson-es-1
# 42  193684604                        opengovernment
# 43   33901216                       bioscholar-v1.0
# 44   13978110                           ProvToolbox
# 45  258719463                         x-spreadsheet
# 46  113915480          expert-pancake-aspnetcoreapp
# 47  223272173                      generalizability
# 48  248895581             Data-Science--Cheat-Sheet
# 49  223627473                  Basketball_Analytics
#
#                                       topics_from_lda
# 0   Protein kinase domain, 0.12012\ncodon, 0.00000...
# 1   Wikidata, 0.03981\ncodon, 0.00000\nUtility lib...
# 2   information, 0.08174\ndata science, 0.00000\ng...
# 3   virtuoso, 0.04775\nvirtuoso, 0.02404\ndocument...
# 4   database, 0.13379\ntextile, 0.00004\nHyperText...
# 5   document, 0.23375\ntextile, 0.00000\ngoods, 0....
# 6   music, 0.02499\nmusic, 0.00000\ncosmology, 0.0...
# 7   cosmology, 0.05597\nmusic, 0.00000\ncatalogue,...
# 8   computer science, 0.06299\ndata science, 0.000...
# 9   music, 0.08406\ndata science, 0.00000\ngoods, ...
# 10  Wikimedia disambiguation page, 0.05756\ndata s...
# 11  codon, 0.18455\nprotein, 0.00000\npipeline tra...
# 12  DNA, 0.05858\nUtility library for structural b...
# 13  pipeline transport, 0.16304\ntextile, 0.00000\...
# 14  library science, 0.03942\nreference work, 0.03...
# 15  software, 0.03133\nUtility library for structu...
# 16  mathematics, 0.10089\ncodon, 0.00000\nUtility ...
# 17  jQuery, 0.17359\ntextile, 0.00000\ndocument, 0...
# 18  Dow Jones Industrial Average, 0.05173\ncell, 0...
# 19  HyperText Markup Language, 0.06091\nwork, 0.00...
# 20  function, 0.06896\ncatalogue, 0.00000\nWikimed...
# 21  Wikimedia disambiguation page, 0.05045\ncosmol...
# 22  Wikimedia disambiguation page, 0.16435\nWikime...
# 23  protein, 0.05685\ncodon, 0.00000\nUtility libr...
# 24  library science, 0.13219\ncodon, 0.00000\ncosm...
# 25  property, 0.07503\npipeline transport, 0.00000...
# 26  graffiti, 0.03924\ncodon, 0.00000\nWikimedia d...
# 27  textile, 0.17843\nwork, 0.00000\ndatabase, 0.0...
# 28  widget toolkit, 0.05759\ncodon, 0.00000\nUtili...
# 29  service, 0.03091\nwidget toolkit, 0.00000\npro...
# 30  work, 0.05929\nWikimedia disambiguation page, ...
# 31  Wikimedia disambiguation page, 0.07382\ncodon,...
# 32  protein, 0.05087\nWikimedia disambiguation pag...
# 33  protein, 0.07934\ngraffiti, 0.00000\ncodon, 0....
# 34  Utility library for structural bioinformatics....
# 35  textile, 0.26935\ngoods, 0.00000\ndata science...
# 36  film, 0.02789\nvirtuoso, 0.00000\npipeline tra...
# 37  catalogue, 0.04883\nlist, 0.03143\nWikimedia d...
# 38  goods, 0.28551\noperation, 0.19025\nWikidata, ...
# 39  minute, 0.05231\njQuery, 0.00000\nminute, 0.00000
# 40  software, 0.06055\ncodon, 0.00000\nUtility lib...
# 41  mathematics, 0.04097\ndocument, 0.00000\nminut...
# 42  document, 0.08755\ntextile, 0.00001\nHyperText...
# 43  system, 0.24100\nWikimedia disambiguation page...
# 44  property, 0.08902\ngoods, 0.00000\ndata scienc...
# 45  cell, 0.22748\nsoftware, 0.00000\nminute, 0.00000
# 46  minute, 0.08224\nminute, 0.00000\ndocument, 0....
# 47  Generalizability of epidemiological findings a...
# 48  data science, 0.32277\npipeline transport, 0.0...
# 49  study, 0.05632\ndocument, 0.00000\njQuery, 0.0...
